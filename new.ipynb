# %%
# Loaded variable 'df' from URI: d:\Lymphography-XAI-Project\data\lymphography.csv
import pandas as pd
df = pd.read_csv(r'd:\Lymphography-XAI-Project\data\lymphography.csv')

# %%
df.head()
# Out:
#    class  lymphatics  block_of_lymph_c  block_of_affere  bl_of_lymph_s  \
# 0      3           4                 2                1              1
# 1      2           3                 2                1              1
# 2      3           3                 2                2              2
# 3      3           3                 1                1              1
# 4      2           3                 1                1              1
#
#    by_pass  extravasates  regeneration  early_uptake  lym_nodes_dimin  \
# 0        1             1             1             2                1
# 1        2             2             1             2                1
# 2        2             2             2             2                1
# 3        1             2             1             2                1
# 4        1             1             1             1                1
#
#    lym_nodes_enlar  changes_in_lym  defect_in_node  changes_in_node  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape
# Out:
# (148, 19)

# %%
df['class'].unique()
